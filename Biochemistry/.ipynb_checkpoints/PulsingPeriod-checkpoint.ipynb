# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

data = pd.read_csv('output.csv',delimiter=',')

# %%
data.head()
# Out:
#      t            Rm            Am            Bm
# 0  0.0  1.290201e-17  1.704911e-36 -3.840375e-74
# 1  0.1  3.500021e-03  1.844018e-28 -7.545870e-66
# 2  0.2  7.000034e-03  6.562008e-28 -2.684223e-65
# 3  0.3  1.050004e-02  1.292256e-27 -5.285383e-65
# 4  0.4  1.400004e-02  1.969428e-27 -8.054543e-65

# %%
data.tail()
# Out:
#             t         Rm        Am        Bm
# 99995  9999.5  43.616305  0.001068  6.372087
# 99996  9999.6  43.619378  0.001067  6.372514
# 99997  9999.7  43.622451  0.001066  6.372940
# 99998  9999.8  43.625525  0.001067  6.373366
# 99999  9999.9  43.628600  0.001068  6.373793

# %%
t = data.t
Rm = data.Rm
Am = data.Am
Bm = data.Bm

# %%
plt.figure(1)
plt.plot(t,Rm)
plt.ylim([0,10])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
Rm_slope = []
for i in range(0,len(t)-1):
    slope = (Rm[i+1] - Rm[i])/(t[i+1]-t[i])
    Rm_slope.append(slope)
Rm_slope.append(Rm_slope[-1])

# %%
plt.figure(2)
plt.plot(t[0:len(Rm_slope)],Rm_slope)
plt.xlim([0,500])
plt.ylim([-0.005,0.005])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# To Do:  Only keep maximums that are greater than a threshold concentration
max = []
t_max = []
for i in range(0,len(Rm_slope)-1):
    if Rm_slope[i]>0 and Rm_slope[i+1]<0 and Rm[i]>0.1:
        max.append(Rm[i+1])
        t_max.append(t[i+1])

plt.figure(10)
plt.plot(t,Rm)
plt.plot(t_max,max, "o", label="max")
plt.ylim([0,4])
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure(11)
plt.hist(np.diff(t_max))
# Out:
# <img src="data:image/png;base64,...">
# (array([ 3.,  7.,  7.,  8.,  8.,  5.,  1.,  0.,  0.,  1.]),
#  array([ 157.3 ,  167.49,  177.68,  187.87,  198.06,  208.25,  218.44,
#          228.63,  238.82,  249.01,  259.2 ]),
#  <a list of 10 Patch objects>)

# %%
np.mean(np.diff(t_max))
# Out:
# 192.16750000000002
